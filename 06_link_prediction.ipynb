# %% [markdown]
# # Link prediction
#
# For two entities _e1_ and _e2_, predict whether the relation _r_ holds between them, e.g., _e1_: Obama, _e2_: USA, _r_: born\_in --> True.
#
# For the link prediction datasets used here as well as several other models optimized for link prediction, check out https://github.com/ibalazevic/HypER and the associated paper.
#
# A SimEc is first trained on all relations combined, then finetuned for individual relations, at which point we use early stopping based on the results on the validation dataset to avoid overfitting.
#
# The parameters chosen here are optimized for the WN18 dataset; for other datasets maybe try training for more epochs or use a different learning rate, etc.

# %%
from __future__ import unicode_literals, division, print_function, absolute_import
from builtins import range
import numpy as np
np.random.seed(28)
import pandas as pd
import tensorflow as tf
tf.set_random_seed(28)
import keras
import keras.backend as K

from copy import deepcopy
from scipy.sparse import dok_matrix, csr_matrix
from simec import SimilarityEncoder

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
def load_data(dataset="WN18", split="train"):
    """
    load the data
    """
    # read in relation data: {relation: {e1: [e2, e4, ...], e2: [e3, e4, ...]}}
    # where entities have new ids matching the matrix indices!
    # always also save the reverse relation and the collected "all" relations that could be used for pretraining
    rel_dict = {"all": {e: [] for e in sorted_entity_ids}}
    df = pd.read_csv("data/link_prediction/%s/%s.txt" % (dataset, split), sep="\t", names=["e1", "rel", "e2"])
    for i, d in df.iterrows():
        if d["rel"] not in rel_dict:
            rel_dict[d["rel"]] = {e: [] for e in sorted_entity_ids}
            rel_dict[d["rel"]+"_reverse"] = {e: [] for e in sorted_entity_ids}
        rel_dict[d["rel"]][entity_ids[d["e1"]]].append(entity_ids[d["e2"]])
        rel_dict[d["rel"]+"_reverse"][entity_ids[d["e2"]]].append(entity_ids[d["e1"]])
        rel_dict["all"][entity_ids[d["e1"]]].append(entity_ids[d["e2"]])
        rel_dict["all"][entity_ids[d["e2"]]].append(entity_ids[d["e1"]])
    return rel_dict


def relation_matrix(entity_dict):
    """
    Build a relations matrix that has 1 where two entities have a relation and 0 else

    Inputs:
        - entity_dict: dict with relations: {e1: [e2, e3, ...]} means entity 1 has relations to 2 and 3
                       i.e. something like rel_train[rel] for one relation

    Returns:
        - n_entities x n_entities relations matrix: for each entity (row), all positions are 1 where this entity
                                                    has a relation with other entities
    """
    n = len(sorted_entity_ids)
    # transform entity relations into sparse matrix
    relmat = dok_matrix((n, n), dtype=np.int8)
    for e1 in entity_dict:
        relmat[e1, entity_dict[e1]] = 1
    relmat = csr_matrix(relmat)
    return relmat


def eval_relpred(model, target_rels, rel, verbose=0):
    """
    Evaluate the relation prediction

    Inputs:
        - model: trained model that gives a score for each entity how likely they have some relation
        - target_rels: dict with all relations, e.g. rel_val
        - rel: which relation we're currently dealing with

    Returns:
        - hits: list of lists, how often the correct entity ranked at or below 1 - 10
        - ranks: actual ranks of target entites
    """
    hits = [[] for i in range(10)]
    ranks = []
    # target_rels is e.g. rel_test
    target_rels = target_rels[rel]
    for e1 in target_rels:
        if target_rels[e1]:
            # predict for the single entity to limit memory consumption
            # this gives one vector with scores
            pred = model.predict(entity_embeddings[e1])[0]
            # for all target objects, save the predicted value
            target_pred = {e2: pred[e2] for e2 in target_rels[e1]}
            # set all true relations to -1 so they don't mess up the ranking
            pred[rel_all[rel][e1]] = -1.
            # get ranks for all object entities
            for e2 in target_rels[e1]:
                pred[e2] = target_pred[e2]
                sort_idx = np.argsort(pred)[::-1]
                rank = np.where(sort_idx == e2)[0][0]
                pred[e2] = -1.
                ranks.append(rank+1)
                for i in range(10):
                    if rank <= i:
                        hits[i].append(1.)
                    else:
                        hits[i].append(0.)
    if verbose:
        print('Hits @10: {0}'.format(np.mean(hits[9])))
        print('Hits @3: {0}'.format(np.mean(hits[2])))
        print('Hits @1: {0}'.format(np.mean(hits[0])))
        print('Median rank: {0}'.format(np.median(ranks)))
        print('Mean rank: {0}'.format(np.mean(ranks)))
        print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks))))
    return hits, ranks

# %%
# first get a list of all entities
dataset = "WN18"
sorted_entities = set()
for split in ["train", "valid", "test"]:
    df = pd.read_csv("data/link_prediction/%s/%s.txt" % (dataset, split), sep="\t", names=["e1", "rel", "e2"])
    sorted_entities |= set(df["e1"]) | set(df["e2"])
sorted_entities = sorted(sorted_entities)
sorted_entity_ids = list(range(len(sorted_entities)))
# get a mapping to the matrix ids for the entities
entity_ids = dict(zip(sorted_entities, sorted_entity_ids))

# read in relation data: {relation: {e1: [e2, e4, ...], e2: [e3, e4, ...]}}
rel_train = load_data(dataset, split="train")
rel_val = load_data(dataset, split="valid")
rel_test = load_data(dataset, split="test")
rels = sorted(rel_train)
# for the FB15K dataset, the validation and test sets are missing some relations
for rel in rels:
    if rel not in rel_val:
        rel_val[rel] = {}
    if rel not in rel_test:
        rel_test[rel] = {}
# for the evaluation we need all true relations between entities
rel_all = deepcopy(rel_train)
for rel in rel_all:
    for e1 in rel_val[rel]:
        rel_all[rel][e1].extend(rel_val[rel][e1])
    for e1 in rel_test[rel]:
        rel_all[rel][e1].extend(rel_test[rel][e1])

# %%
# get a sparse input matrix that just has ones on the diagonal
entity_embeddings = dok_matrix((len(sorted_entity_ids), len(sorted_entity_ids)), dtype=np.int8)
for i in sorted_entity_ids:
    entity_embeddings[i, i] = 1
entity_embeddings = csr_matrix(entity_embeddings)
inputs = entity_embeddings
# get target matrix for all relations at once
rel = "all"
relmat = relation_matrix(rel_train[rel])

# pretraining of the simec to predict all relations
e_dim = 100
simec = SimilarityEncoder(inputs.shape[1], e_dim, relmat.shape[1], sparse_inputs=True, l2_reg=0., l2_reg_emb=0., l2_reg_out=0.,
                          hidden_layers=[(e_dim, 'linear')], ll_activation="sigmoid", loss="binary_crossentropy", opt=0.001)
# train the simec for a loooong time and save the weights for later
simec.fit(inputs, relmat, epochs=600, batch_size=32, verbose=0)
pretrained_weights = deepcopy(simec.model.get_weights())

# evaluate: on all relations combined (like it was trained)
print("#####################")
print("rel = all")
print("#####################")
print("on training data")
hits_rel, ranks_rel = eval_relpred(simec, rel_train, rel, 1)
print("on validation data")
hits_rel, ranks_rel = eval_relpred(simec, rel_val, rel, 1)
print("on test data")
hits_rel, ranks_rel = eval_relpred(simec, rel_test, rel, 1)
# and on the individual relations
hits_train = [[] for i in range(10)]
ranks_train = []
hits_val = [[] for i in range(10)]
ranks_val = []
hits_test = [[] for i in range(10)]
ranks_test = []
for rel in rels:
    if rel == "all":
        continue
    hits_rel, ranks_rel = eval_relpred(simec, rel_train, rel, 0)
    ranks_train.extend(ranks_rel)
    for i in range(10):
        hits_train[i].extend(hits_rel[i])
    hits_rel, ranks_rel = eval_relpred(simec, rel_val, rel, 0)
    ranks_val.extend(ranks_rel)
    for i in range(10):
        hits_val[i].extend(hits_rel[i])
    hits_rel, ranks_rel = eval_relpred(simec, rel_test, rel, 0)
    ranks_test.extend(ranks_rel)
    for i in range(10):
        hits_test[i].extend(hits_rel[i])
print("#####################")
print("averaged results")
print("#####################")
print("on training data")
print('Hits @10: {0}'.format(np.mean(hits_train[9])))
print('Hits @3: {0}'.format(np.mean(hits_train[2])))
print('Hits @1: {0}'.format(np.mean(hits_train[0])))
print('Median rank: {0}'.format(np.median(ranks_train)))
print('Mean rank: {0}'.format(np.mean(ranks_train)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_train))))
print("on validation data")
print('Hits @10: {0}'.format(np.mean(hits_val[9])))
print('Hits @3: {0}'.format(np.mean(hits_val[2])))
print('Hits @1: {0}'.format(np.mean(hits_val[0])))
print('Median rank: {0}'.format(np.median(ranks_val)))
print('Mean rank: {0}'.format(np.mean(ranks_val)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_val))))
print("on testing data")
print('Hits @10: {0}'.format(np.mean(hits_test[9])))
print('Hits @3: {0}'.format(np.mean(hits_test[2])))
print('Hits @1: {0}'.format(np.mean(hits_test[0])))
print('Median rank: {0}'.format(np.median(ranks_test)))
print('Mean rank: {0}'.format(np.mean(ranks_test)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_test))))
K.clear_session()
# Out:
# #####################
# rel = all
# #####################
# on training data
# Hits @10: 0.9986849733459652
# Hits @3: 0.9986849733459652
# Hits @1: 0.9863725060448806
# Median rank: 1.0
# Mean rank: 47.314149969598844
# Mean reciprocal rank: 0.9925287891494851
# on validation data
# Hits @10: 0.9436
# Hits @3: 0.9413
# Hits @1: 0.9277
# Median rank: 1.0
# Mean rank: 590.1773
# Mean reciprocal rank: 0.9351175533901909
# on test data
# Hits @10: 0.9441
# Hits @3: 0.9422
# Hits @1: 0.9291
# Median rank: 1.0
# Mean rank: 562.3184
# Mean reciprocal rank: 0.9362221394366322
# #####################
# averaged results
# #####################
# on training data
# Hits @10: 0.9762517498338542
# Hits @3: 0.8500410062074915
# Hits @1: 0.3790564330255511
# Median rank: 2.0
# Mean rank: 49.11410684238062
# Mean reciprocal rank: 0.6164161122552798
# on validation data
# Hits @10: 0.9181
# Hits @3: 0.795
# Hits @1: 0.3562
# Median rank: 2.0
# Mean rank: 592.4728
# Mean reciprocal rank: 0.5786867582163843
# on testing data
# Hits @10: 0.9216
# Hits @3: 0.7927
# Hits @1: 0.3493
# Median rank: 2.0
# Mean rank: 564.4649
# Mean reciprocal rank: 0.5758652330358736

# %%
# simec finetuning for all other rels
hits_train = [[] for i in range(10)]
ranks_train = []
hits_val = [[] for i in range(10)]
ranks_val = []
hits_test = [[] for i in range(10)]
ranks_test = []
for rel in rels:
    if rel == "all" or not rel_val[rel] or not rel_test[rel]:
        continue
    print(rel)
    # get relation matrix e1 -> e2
    relmat = relation_matrix(rel_train[rel])
    # we only train on the entities for which we actually have relations
    e1_idx = sorted(e1 for e1 in rel_train[rel] if rel_train[rel][e1])
    relmat = relmat[e1_idx]
    inputs = entity_embeddings[e1_idx]
    simec = SimilarityEncoder(inputs.shape[1], e_dim, relmat.shape[1], sparse_inputs=True, l2_reg=0., l2_reg_emb=0., l2_reg_out=0.,
                              hidden_layers=[(e_dim, 'linear')], ll_activation="sigmoid", loss="binary_crossentropy", opt=0.001)
    # set weights with pretrained weights
    simec.model.set_weights(pretrained_weights)
    # based on the validation data we do early stopping and save the best weights
    _, ranks_rel = eval_relpred(simec, rel_val, rel)
    best_mrr = np.mean(1./np.array(ranks_rel))
    best_epoch = 0
    best_weights = deepcopy(simec.model.get_weights())
    for i in range(1, 51):
        simec.fit(inputs, relmat, epochs=3, batch_size=128, verbose=0)
        # evaluate on validation data to avoid overfitting
        _, ranks_rel = eval_relpred(simec, rel_val, rel)
        mrr = np.mean(1./np.array(ranks_rel))
        if mrr > best_mrr:
            best_mrr = mrr
            best_epoch = i*3
            best_weights = deepcopy(simec.model.get_weights())
        elif i*3 > 25:
            break
        print("MRR after %i epochs: %.7f (best: %.7f; epoch %i)" % (i*3, mrr, best_mrr, best_epoch))
    simec.model.set_weights(best_weights)
    # evaluate
    hits_rel, ranks_rel = eval_relpred(simec, rel_train, rel, 0)
    ranks_train.extend(ranks_rel)
    for i in range(10):
        hits_train[i].extend(hits_rel[i])
    hits_rel, ranks_rel = eval_relpred(simec, rel_val, rel, 0)
    ranks_val.extend(ranks_rel)
    for i in range(10):
        hits_val[i].extend(hits_rel[i])
    hits_rel, ranks_rel = eval_relpred(simec, rel_test, rel, 0)
    ranks_test.extend(ranks_rel)
    for i in range(10):
        hits_test[i].extend(hits_rel[i])
    K.clear_session()
# Out:
# _also_see
# MRR after 3 epochs: 0.4777593 (best: 0.4777593; epoch 3)
# MRR after 6 epochs: 0.5395365 (best: 0.5395365; epoch 6)
# MRR after 9 epochs: 0.5395525 (best: 0.5395525; epoch 9)
# MRR after 12 epochs: 0.5436544 (best: 0.5436544; epoch 12)
# MRR after 15 epochs: 0.5436306 (best: 0.5436544; epoch 12)
# MRR after 18 epochs: 0.5436331 (best: 0.5436544; epoch 12)
# MRR after 21 epochs: 0.5436366 (best: 0.5436544; epoch 12)
# MRR after 24 epochs: 0.5558330 (best: 0.5558330; epoch 24)
# MRR after 27 epochs: 0.5558339 (best: 0.5558339; epoch 27)
# MRR after 30 epochs: 0.5571056 (best: 0.5571056; epoch 30)
# _also_see_reverse
# MRR after 3 epochs: 0.5238476 (best: 0.5238476; epoch 3)
# MRR after 6 epochs: 0.5743383 (best: 0.5743383; epoch 6)
# MRR after 9 epochs: 0.5744536 (best: 0.5744536; epoch 9)
# MRR after 12 epochs: 0.5745943 (best: 0.5745943; epoch 12)
# MRR after 15 epochs: 0.5746400 (best: 0.5746400; epoch 15)
# MRR after 18 epochs: 0.5747116 (best: 0.5747116; epoch 18)
# MRR after 21 epochs: 0.5747690 (best: 0.5747690; epoch 21)
# MRR after 24 epochs: 0.5748420 (best: 0.5748420; epoch 24)
# MRR after 27 epochs: 0.5749163 (best: 0.5749163; epoch 27)
# MRR after 30 epochs: 0.5749896 (best: 0.5749896; epoch 30)
# MRR after 33 epochs: 0.5750921 (best: 0.5750921; epoch 33)
# MRR after 36 epochs: 0.5751925 (best: 0.5751925; epoch 36)
# MRR after 39 epochs: 0.5752182 (best: 0.5752182; epoch 39)
# MRR after 42 epochs: 0.5752423 (best: 0.5752423; epoch 42)
# MRR after 45 epochs: 0.5752559 (best: 0.5752559; epoch 45)
# MRR after 48 epochs: 0.5753134 (best: 0.5753134; epoch 48)
# MRR after 51 epochs: 0.5753245 (best: 0.5753245; epoch 51)
# MRR after 54 epochs: 0.5753455 (best: 0.5753455; epoch 54)
# MRR after 57 epochs: 0.5753707 (best: 0.5753707; epoch 57)
# MRR after 60 epochs: 0.5754158 (best: 0.5754158; epoch 60)
# MRR after 63 epochs: 0.5754315 (best: 0.5754315; epoch 63)
# MRR after 66 epochs: 0.5754360 (best: 0.5754360; epoch 66)
# MRR after 69 epochs: 0.5754973 (best: 0.5754973; epoch 69)
# MRR after 72 epochs: 0.5756006 (best: 0.5756006; epoch 72)
# MRR after 75 epochs: 0.5756899 (best: 0.5756899; epoch 75)
# MRR after 78 epochs: 0.5757267 (best: 0.5757267; epoch 78)
# MRR after 81 epochs: 0.5758023 (best: 0.5758023; epoch 81)
# MRR after 84 epochs: 0.5758723 (best: 0.5758723; epoch 84)
# MRR after 87 epochs: 0.5760339 (best: 0.5760339; epoch 87)
# MRR after 90 epochs: 0.5761330 (best: 0.5761330; epoch 90)
# MRR after 93 epochs: 0.5761531 (best: 0.5761531; epoch 93)
# MRR after 96 epochs: 0.5761547 (best: 0.5761547; epoch 96)
# MRR after 99 epochs: 0.5761772 (best: 0.5761772; epoch 99)
# _derivationally_related_form
# MRR after 3 epochs: 0.6330774 (best: 0.6330774; epoch 3)
# MRR after 6 epochs: 0.6388446 (best: 0.6388446; epoch 6)
# MRR after 9 epochs: 0.6431437 (best: 0.6431437; epoch 9)
# MRR after 12 epochs: 0.6456947 (best: 0.6456947; epoch 12)
# MRR after 15 epochs: 0.6444549 (best: 0.6456947; epoch 12)
# MRR after 18 epochs: 0.6423856 (best: 0.6456947; epoch 12)
# MRR after 21 epochs: 0.6449127 (best: 0.6456947; epoch 12)
# MRR after 24 epochs: 0.6388126 (best: 0.6456947; epoch 12)
# _derivationally_related_form_reverse
# MRR after 3 epochs: 0.6417729 (best: 0.6417729; epoch 3)
# MRR after 6 epochs: 0.6472967 (best: 0.6472967; epoch 6)
# MRR after 9 epochs: 0.6494967 (best: 0.6494967; epoch 9)
# MRR after 12 epochs: 0.6481763 (best: 0.6494967; epoch 9)
# MRR after 15 epochs: 0.6500446 (best: 0.6500446; epoch 15)
# MRR after 18 epochs: 0.6520426 (best: 0.6520426; epoch 18)
# MRR after 21 epochs: 0.6514386 (best: 0.6520426; epoch 18)
# MRR after 24 epochs: 0.6485424 (best: 0.6520426; epoch 18)
# _has_part
# MRR after 3 epochs: 0.5833994 (best: 0.5833994; epoch 3)
# MRR after 6 epochs: 0.5996943 (best: 0.5996943; epoch 6)
# MRR after 9 epochs: 0.6004675 (best: 0.6004675; epoch 9)
# MRR after 12 epochs: 0.5997101 (best: 0.6004675; epoch 9)
# MRR after 15 epochs: 0.6051115 (best: 0.6051115; epoch 15)
# MRR after 18 epochs: 0.6244800 (best: 0.6244800; epoch 18)
# MRR after 21 epochs: 0.6317027 (best: 0.6317027; epoch 21)
# MRR after 24 epochs: 0.6269580 (best: 0.6317027; epoch 21)
# _has_part_reverse
# MRR after 3 epochs: 0.8184656 (best: 0.8184656; epoch 3)
# MRR after 6 epochs: 0.8400959 (best: 0.8400959; epoch 6)
# MRR after 9 epochs: 0.8433124 (best: 0.8433124; epoch 9)
# MRR after 12 epochs: 0.8433525 (best: 0.8433525; epoch 12)
# MRR after 15 epochs: 0.8437087 (best: 0.8437087; epoch 15)
# MRR after 18 epochs: 0.8439616 (best: 0.8439616; epoch 18)
# MRR after 21 epochs: 0.8439616 (best: 0.8439616; epoch 18)
# MRR after 24 epochs: 0.8439138 (best: 0.8439616; epoch 18)
# MRR after 27 epochs: 0.8455374 (best: 0.8455374; epoch 27)
# MRR after 30 epochs: 0.8455496 (best: 0.8455496; epoch 30)
# MRR after 33 epochs: 0.8466200 (best: 0.8466200; epoch 33)
# _hypernym
# MRR after 3 epochs: 0.8267477 (best: 0.8267477; epoch 3)
# MRR after 6 epochs: 0.8327468 (best: 0.8327468; epoch 6)
# MRR after 9 epochs: 0.8392879 (best: 0.8392879; epoch 9)
# MRR after 12 epochs: 0.8375562 (best: 0.8392879; epoch 9)
# MRR after 15 epochs: 0.8379338 (best: 0.8392879; epoch 9)
# MRR after 18 epochs: 0.8354630 (best: 0.8392879; epoch 9)
# MRR after 21 epochs: 0.8363158 (best: 0.8392879; epoch 9)
# MRR after 24 epochs: 0.8353419 (best: 0.8392879; epoch 9)
# _hypernym_reverse
# MRR after 3 epochs: 0.5285668 (best: 0.5285668; epoch 3)
# MRR after 6 epochs: 0.5046335 (best: 0.5285668; epoch 3)
# MRR after 9 epochs: 0.4983067 (best: 0.5285668; epoch 3)
# MRR after 12 epochs: 0.4950975 (best: 0.5285668; epoch 3)
# MRR after 15 epochs: 0.4983319 (best: 0.5285668; epoch 3)
# MRR after 18 epochs: 0.5006387 (best: 0.5285668; epoch 3)
# MRR after 21 epochs: 0.4998262 (best: 0.5285668; epoch 3)
# MRR after 24 epochs: 0.4990847 (best: 0.5285668; epoch 3)
# _hyponym
# MRR after 3 epochs: 0.5347049 (best: 0.5347049; epoch 3)
# MRR after 6 epochs: 0.5184746 (best: 0.5347049; epoch 3)
# MRR after 9 epochs: 0.5159131 (best: 0.5347049; epoch 3)
# MRR after 12 epochs: 0.5111899 (best: 0.5347049; epoch 3)
# MRR after 15 epochs: 0.5117256 (best: 0.5347049; epoch 3)
# MRR after 18 epochs: 0.5103694 (best: 0.5347049; epoch 3)
# MRR after 21 epochs: 0.5110940 (best: 0.5347049; epoch 3)
# MRR after 24 epochs: 0.5090556 (best: 0.5347049; epoch 3)
# _hyponym_reverse
# MRR after 3 epochs: 0.8470944 (best: 0.8470944; epoch 3)
# MRR after 6 epochs: 0.8526725 (best: 0.8526725; epoch 6)
# MRR after 9 epochs: 0.8567837 (best: 0.8567837; epoch 9)
# MRR after 12 epochs: 0.8559519 (best: 0.8567837; epoch 9)
# MRR after 15 epochs: 0.8578801 (best: 0.8578801; epoch 15)
# MRR after 18 epochs: 0.8548860 (best: 0.8578801; epoch 15)
# MRR after 21 epochs: 0.8544522 (best: 0.8578801; epoch 15)
# MRR after 24 epochs: 0.8530952 (best: 0.8578801; epoch 15)
# _instance_hypernym
# MRR after 3 epochs: 0.9727485 (best: 0.9727485; epoch 3)
# MRR after 6 epochs: 0.9727762 (best: 0.9727762; epoch 6)
# MRR after 9 epochs: 0.9727913 (best: 0.9727913; epoch 9)
# MRR after 12 epochs: 0.9728613 (best: 0.9728613; epoch 12)
# MRR after 15 epochs: 0.9728892 (best: 0.9728892; epoch 15)
# MRR after 18 epochs: 0.9776004 (best: 0.9776004; epoch 18)
# MRR after 21 epochs: 0.9777158 (best: 0.9777158; epoch 21)
# MRR after 24 epochs: 0.9777738 (best: 0.9777738; epoch 24)
# MRR after 27 epochs: 0.9778037 (best: 0.9778037; epoch 27)
# _instance_hypernym_reverse
# MRR after 3 epochs: 0.6207516 (best: 0.6207516; epoch 3)
# MRR after 6 epochs: 0.6899249 (best: 0.6899249; epoch 6)
# MRR after 9 epochs: 0.6911626 (best: 0.6911626; epoch 9)
# MRR after 12 epochs: 0.6918902 (best: 0.6918902; epoch 12)
# MRR after 15 epochs: 0.7022032 (best: 0.7022032; epoch 15)
# MRR after 18 epochs: 0.7063329 (best: 0.7063329; epoch 18)
# MRR after 21 epochs: 0.6969845 (best: 0.7063329; epoch 18)
# MRR after 24 epochs: 0.6973037 (best: 0.7063329; epoch 18)
# _instance_hyponym
# MRR after 3 epochs: 0.6057621 (best: 0.6057621; epoch 3)
# MRR after 6 epochs: 0.6702752 (best: 0.6702752; epoch 6)
# MRR after 9 epochs: 0.7005177 (best: 0.7005177; epoch 9)
# MRR after 12 epochs: 0.7244994 (best: 0.7244994; epoch 12)
# MRR after 15 epochs: 0.7222647 (best: 0.7244994; epoch 12)
# MRR after 18 epochs: 0.7214857 (best: 0.7244994; epoch 12)
# MRR after 21 epochs: 0.7252056 (best: 0.7252056; epoch 21)
# MRR after 24 epochs: 0.7259781 (best: 0.7259781; epoch 24)
# MRR after 27 epochs: 0.7275350 (best: 0.7275350; epoch 27)
# _instance_hyponym_reverse
# MRR after 3 epochs: 0.9589354 (best: 0.9589354; epoch 3)
# MRR after 6 epochs: 0.9581349 (best: 0.9589354; epoch 3)
# MRR after 9 epochs: 0.9576676 (best: 0.9589354; epoch 3)
# MRR after 12 epochs: 0.9576994 (best: 0.9589354; epoch 3)
# MRR after 15 epochs: 0.9576994 (best: 0.9589354; epoch 3)
# MRR after 18 epochs: 0.9576994 (best: 0.9589354; epoch 3)
# MRR after 21 epochs: 0.9577228 (best: 0.9589354; epoch 3)
# MRR after 24 epochs: 0.9623894 (best: 0.9623894; epoch 24)
# MRR after 27 epochs: 0.9624024 (best: 0.9624024; epoch 27)
# MRR after 30 epochs: 0.9624094 (best: 0.9624094; epoch 30)
# MRR after 33 epochs: 0.9624168 (best: 0.9624168; epoch 33)
# MRR after 36 epochs: 0.9624246 (best: 0.9624246; epoch 36)
# _member_holonym
# MRR after 3 epochs: 0.8667562 (best: 0.8667562; epoch 3)
# MRR after 6 epochs: 0.8835485 (best: 0.8835485; epoch 6)
# MRR after 9 epochs: 0.8850220 (best: 0.8850220; epoch 9)
# MRR after 12 epochs: 0.8852798 (best: 0.8852798; epoch 12)
# MRR after 15 epochs: 0.8903143 (best: 0.8903143; epoch 15)
# MRR after 18 epochs: 0.8904617 (best: 0.8904617; epoch 18)
# MRR after 21 epochs: 0.8906724 (best: 0.8906724; epoch 21)
# MRR after 24 epochs: 0.8963625 (best: 0.8963625; epoch 24)
# MRR after 27 epochs: 0.8975057 (best: 0.8975057; epoch 27)
# MRR after 30 epochs: 0.9011453 (best: 0.9011453; epoch 30)
# MRR after 33 epochs: 0.9023605 (best: 0.9023605; epoch 33)
# MRR after 36 epochs: 0.9042259 (best: 0.9042259; epoch 36)
# MRR after 39 epochs: 0.9042880 (best: 0.9042880; epoch 39)
# _member_holonym_reverse
# MRR after 3 epochs: 0.8062880 (best: 0.8062880; epoch 3)
# MRR after 6 epochs: 0.7790669 (best: 0.8062880; epoch 3)
# MRR after 9 epochs: 0.7697272 (best: 0.8062880; epoch 3)
# MRR after 12 epochs: 0.7734516 (best: 0.8062880; epoch 3)
# MRR after 15 epochs: 0.7734458 (best: 0.8062880; epoch 3)
# MRR after 18 epochs: 0.7734419 (best: 0.8062880; epoch 3)
# MRR after 21 epochs: 0.7753033 (best: 0.8062880; epoch 3)
# MRR after 24 epochs: 0.7846265 (best: 0.8062880; epoch 3)
# _member_meronym
# MRR after 3 epochs: 0.8168332 (best: 0.8168332; epoch 3)
# MRR after 6 epochs: 0.8015379 (best: 0.8168332; epoch 3)
# MRR after 9 epochs: 0.7912065 (best: 0.8168332; epoch 3)
# MRR after 12 epochs: 0.7905941 (best: 0.8168332; epoch 3)
# MRR after 15 epochs: 0.7887559 (best: 0.8168332; epoch 3)
# MRR after 18 epochs: 0.7898815 (best: 0.8168332; epoch 3)
# MRR after 21 epochs: 0.7891956 (best: 0.8168332; epoch 3)
# MRR after 24 epochs: 0.7910176 (best: 0.8168332; epoch 3)
# _member_meronym_reverse
# MRR after 3 epochs: 0.8502494 (best: 0.8502494; epoch 3)
# MRR after 6 epochs: 0.8822833 (best: 0.8822833; epoch 6)
# MRR after 9 epochs: 0.8830510 (best: 0.8830510; epoch 9)
# MRR after 12 epochs: 0.8832029 (best: 0.8832029; epoch 12)
# MRR after 15 epochs: 0.8851828 (best: 0.8851828; epoch 15)
# MRR after 18 epochs: 0.8881824 (best: 0.8881824; epoch 18)
# MRR after 21 epochs: 0.8898450 (best: 0.8898450; epoch 21)
# MRR after 24 epochs: 0.8901080 (best: 0.8901080; epoch 24)
# MRR after 27 epochs: 0.8901358 (best: 0.8901358; epoch 27)
# MRR after 30 epochs: 0.8901471 (best: 0.8901471; epoch 30)
# _member_of_domain_region
# MRR after 3 epochs: 0.1338329 (best: 0.1338329; epoch 3)
# MRR after 6 epochs: 0.1751051 (best: 0.1751051; epoch 6)
# MRR after 9 epochs: 0.2141805 (best: 0.2141805; epoch 9)
# MRR after 12 epochs: 0.2489506 (best: 0.2489506; epoch 12)
# MRR after 15 epochs: 0.2303398 (best: 0.2489506; epoch 12)
# MRR after 18 epochs: 0.2120988 (best: 0.2489506; epoch 12)
# MRR after 21 epochs: 0.1842194 (best: 0.2489506; epoch 12)
# MRR after 24 epochs: 0.1657726 (best: 0.2489506; epoch 12)
# _member_of_domain_region_reverse
# MRR after 3 epochs: 0.8970603 (best: 0.8970603; epoch 3)
# MRR after 6 epochs: 0.9411779 (best: 0.9411779; epoch 6)
# MRR after 9 epochs: 0.9411779 (best: 0.9411779; epoch 9)
# MRR after 12 epochs: 0.9411779 (best: 0.9411779; epoch 9)
# MRR after 15 epochs: 0.9411779 (best: 0.9411779; epoch 9)
# MRR after 18 epochs: 0.9411779 (best: 0.9411779; epoch 9)
# MRR after 21 epochs: 0.9411779 (best: 0.9411779; epoch 9)
# MRR after 24 epochs: 0.9411779 (best: 0.9411779; epoch 24)
# _member_of_domain_topic
# MRR after 3 epochs: 0.4606973 (best: 0.4606973; epoch 3)
# MRR after 6 epochs: 0.4649725 (best: 0.4649725; epoch 6)
# MRR after 9 epochs: 0.4569024 (best: 0.4649725; epoch 6)
# MRR after 12 epochs: 0.4808063 (best: 0.4808063; epoch 12)
# MRR after 15 epochs: 0.4905308 (best: 0.4905308; epoch 15)
# MRR after 18 epochs: 0.4947536 (best: 0.4947536; epoch 18)
# MRR after 21 epochs: 0.4989203 (best: 0.4989203; epoch 21)
# MRR after 24 epochs: 0.5001923 (best: 0.5001923; epoch 24)
# _member_of_domain_topic_reverse
# MRR after 3 epochs: 0.8996197 (best: 0.8996197; epoch 3)
# MRR after 6 epochs: 0.9047636 (best: 0.9047636; epoch 6)
# MRR after 9 epochs: 0.9104300 (best: 0.9104300; epoch 9)
# MRR after 12 epochs: 0.9193635 (best: 0.9193635; epoch 12)
# MRR after 15 epochs: 0.9193730 (best: 0.9193730; epoch 15)
# MRR after 18 epochs: 0.9193809 (best: 0.9193809; epoch 18)
# MRR after 21 epochs: 0.9193923 (best: 0.9193923; epoch 21)
# MRR after 24 epochs: 0.9194055 (best: 0.9194055; epoch 24)
# MRR after 27 epochs: 0.9194178 (best: 0.9194178; epoch 27)
# MRR after 30 epochs: 0.9194285 (best: 0.9194285; epoch 30)
# MRR after 33 epochs: 0.9194405 (best: 0.9194405; epoch 33)
# MRR after 36 epochs: 0.9239161 (best: 0.9239161; epoch 36)
# MRR after 39 epochs: 0.9239196 (best: 0.9239196; epoch 39)
# MRR after 42 epochs: 0.9239369 (best: 0.9239369; epoch 42)
# MRR after 45 epochs: 0.9239415 (best: 0.9239415; epoch 45)
# MRR after 48 epochs: 0.9239583 (best: 0.9239583; epoch 48)
# MRR after 51 epochs: 0.9239738 (best: 0.9239738; epoch 51)
# MRR after 54 epochs: 0.9239800 (best: 0.9239800; epoch 54)
# MRR after 57 epochs: 0.9239859 (best: 0.9239859; epoch 57)
# MRR after 60 epochs: 0.9239988 (best: 0.9239988; epoch 60)
# MRR after 63 epochs: 0.9240059 (best: 0.9240059; epoch 63)
# MRR after 66 epochs: 0.9240357 (best: 0.9240357; epoch 66)
# MRR after 69 epochs: 0.9240365 (best: 0.9240365; epoch 69)
# MRR after 72 epochs: 0.9240372 (best: 0.9240372; epoch 72)
# MRR after 75 epochs: 0.9240468 (best: 0.9240468; epoch 75)
# MRR after 78 epochs: 0.9331764 (best: 0.9331764; epoch 78)
# MRR after 81 epochs: 0.9331815 (best: 0.9331815; epoch 81)
# MRR after 84 epochs: 0.9331845 (best: 0.9331845; epoch 84)
# MRR after 87 epochs: 0.9331872 (best: 0.9331872; epoch 87)
# MRR after 90 epochs: 0.9331885 (best: 0.9331885; epoch 90)
# MRR after 93 epochs: 0.9331899 (best: 0.9331899; epoch 93)
# MRR after 96 epochs: 0.9331911 (best: 0.9331911; epoch 96)
# MRR after 99 epochs: 0.9332215 (best: 0.9332215; epoch 99)
# MRR after 102 epochs: 0.9332224 (best: 0.9332224; epoch 102)
# MRR after 105 epochs: 0.9332237 (best: 0.9332237; epoch 105)
# MRR after 108 epochs: 0.9332575 (best: 0.9332575; epoch 108)
# MRR after 111 epochs: 0.9333386 (best: 0.9333386; epoch 111)
# MRR after 114 epochs: 0.9333401 (best: 0.9333401; epoch 114)
# MRR after 117 epochs: 0.9334474 (best: 0.9334474; epoch 117)
# MRR after 120 epochs: 0.9334486 (best: 0.9334486; epoch 120)
# MRR after 123 epochs: 0.9334501 (best: 0.9334501; epoch 123)
# MRR after 126 epochs: 0.9335191 (best: 0.9335191; epoch 126)
# _member_of_domain_usage
# MRR after 3 epochs: 0.7041820 (best: 0.7041820; epoch 3)
# MRR after 6 epochs: 0.7121366 (best: 0.7121366; epoch 6)
# MRR after 9 epochs: 0.7742580 (best: 0.7742580; epoch 9)
# MRR after 12 epochs: 0.7689549 (best: 0.7742580; epoch 9)
# MRR after 15 epochs: 0.3967146 (best: 0.7742580; epoch 9)
# MRR after 18 epochs: 0.3099483 (best: 0.7742580; epoch 9)
# MRR after 21 epochs: 0.2307158 (best: 0.7742580; epoch 9)
# MRR after 24 epochs: 0.1959596 (best: 0.7742580; epoch 9)
# _member_of_domain_usage_reverse
# MRR after 3 epochs: 0.8750024 (best: 0.8750024; epoch 3)
# MRR after 6 epochs: 0.9090934 (best: 0.9090934; epoch 6)
# MRR after 9 epochs: 0.9090934 (best: 0.9090934; epoch 9)
# MRR after 12 epochs: 0.9090934 (best: 0.9090934; epoch 12)
# MRR after 15 epochs: 0.9090934 (best: 0.9090934; epoch 15)
# MRR after 18 epochs: 0.9090934 (best: 0.9090934; epoch 18)
# MRR after 21 epochs: 0.9090934 (best: 0.9090934; epoch 21)
# MRR after 24 epochs: 0.9090934 (best: 0.9090934; epoch 24)
# MRR after 27 epochs: 0.9090934 (best: 0.9090934; epoch 27)
# MRR after 30 epochs: 0.9090934 (best: 0.9090934; epoch 30)
# MRR after 33 epochs: 0.9090934 (best: 0.9090934; epoch 33)
# MRR after 36 epochs: 0.9090934 (best: 0.9090934; epoch 36)
# MRR after 39 epochs: 0.9090934 (best: 0.9090934; epoch 39)
# MRR after 42 epochs: 0.9090934 (best: 0.9090934; epoch 42)
# MRR after 45 epochs: 0.9090934 (best: 0.9090934; epoch 45)
# MRR after 48 epochs: 0.9090934 (best: 0.9090934; epoch 48)
# MRR after 51 epochs: 0.9090934 (best: 0.9090934; epoch 51)
# MRR after 54 epochs: 0.9090935 (best: 0.9090935; epoch 54)
# MRR after 57 epochs: 0.9090935 (best: 0.9090935; epoch 57)
# MRR after 60 epochs: 0.9090935 (best: 0.9090935; epoch 60)
# MRR after 63 epochs: 0.9090935 (best: 0.9090935; epoch 63)
# _part_of
# MRR after 3 epochs: 0.8512232 (best: 0.8512232; epoch 3)
# MRR after 6 epochs: 0.8572302 (best: 0.8572302; epoch 6)
# MRR after 9 epochs: 0.8516369 (best: 0.8572302; epoch 6)
# MRR after 12 epochs: 0.8586602 (best: 0.8586602; epoch 12)
# MRR after 15 epochs: 0.8587240 (best: 0.8587240; epoch 15)
# MRR after 18 epochs: 0.8587247 (best: 0.8587247; epoch 18)
# MRR after 21 epochs: 0.8559607 (best: 0.8587247; epoch 18)
# MRR after 24 epochs: 0.8564293 (best: 0.8587247; epoch 18)
# _part_of_reverse
# MRR after 3 epochs: 0.6007936 (best: 0.6007936; epoch 3)
# MRR after 6 epochs: 0.6263899 (best: 0.6263899; epoch 6)
# MRR after 9 epochs: 0.6158530 (best: 0.6263899; epoch 6)
# MRR after 12 epochs: 0.6242172 (best: 0.6263899; epoch 6)
# MRR after 15 epochs: 0.6204377 (best: 0.6263899; epoch 6)
# MRR after 18 epochs: 0.6244553 (best: 0.6263899; epoch 6)
# MRR after 21 epochs: 0.6258656 (best: 0.6263899; epoch 6)
# MRR after 24 epochs: 0.6234825 (best: 0.6263899; epoch 6)
# MRR after 27 epochs: 0.6274791 (best: 0.6274791; epoch 27)
# MRR after 30 epochs: 0.6310622 (best: 0.6310622; epoch 30)
# _similar_to
# MRR after 3 epochs: 0.6666667 (best: 0.6666667; epoch 3)
# MRR after 6 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 9 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 12 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 15 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 18 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 21 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# MRR after 24 epochs: 0.8333333 (best: 0.8333333; epoch 6)
# _similar_to_reverse
# MRR after 3 epochs: 0.5111111 (best: 0.5277778; epoch 0)
# MRR after 6 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 9 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 12 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 15 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 18 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 21 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# MRR after 24 epochs: 0.3611111 (best: 0.5277778; epoch 0)
# _synset_domain_region_of
# MRR after 3 epochs: 0.8803867 (best: 0.8803867; epoch 3)
# MRR after 6 epochs: 0.9200692 (best: 0.9200692; epoch 6)
# MRR after 9 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# MRR after 12 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# MRR after 15 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# MRR after 18 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# MRR after 21 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# MRR after 24 epochs: 0.9200692 (best: 0.9200692; epoch 9)
# _synset_domain_region_of_reverse
# MRR after 3 epochs: 0.2076510 (best: 0.2076510; epoch 3)
# MRR after 6 epochs: 0.2289332 (best: 0.2289332; epoch 6)
# MRR after 9 epochs: 0.3006016 (best: 0.3006016; epoch 9)
# MRR after 12 epochs: 0.3147821 (best: 0.3147821; epoch 12)
# MRR after 15 epochs: 0.3295919 (best: 0.3295919; epoch 15)
# MRR after 18 epochs: 0.3108423 (best: 0.3295919; epoch 15)
# MRR after 21 epochs: 0.2831353 (best: 0.3295919; epoch 15)
# MRR after 24 epochs: 0.2665111 (best: 0.3295919; epoch 15)
# _synset_domain_topic_of
# MRR after 3 epochs: 0.9376360 (best: 0.9376360; epoch 3)
# MRR after 6 epochs: 0.9423973 (best: 0.9423973; epoch 6)
# MRR after 9 epochs: 0.9423986 (best: 0.9423986; epoch 9)
# MRR after 12 epochs: 0.9376379 (best: 0.9423986; epoch 9)
# MRR after 15 epochs: 0.9424009 (best: 0.9424009; epoch 15)
# MRR after 18 epochs: 0.9376403 (best: 0.9424009; epoch 15)
# MRR after 21 epochs: 0.9360542 (best: 0.9424009; epoch 15)
# MRR after 24 epochs: 0.9360548 (best: 0.9424009; epoch 15)
# _synset_domain_topic_of_reverse
# MRR after 3 epochs: 0.4300833 (best: 0.4300833; epoch 3)
# MRR after 6 epochs: 0.4508690 (best: 0.4508690; epoch 6)
# MRR after 9 epochs: 0.4754350 (best: 0.4754350; epoch 9)
# MRR after 12 epochs: 0.4682373 (best: 0.4754350; epoch 9)
# MRR after 15 epochs: 0.4632427 (best: 0.4754350; epoch 9)
# MRR after 18 epochs: 0.4643276 (best: 0.4754350; epoch 9)
# MRR after 21 epochs: 0.4659121 (best: 0.4754350; epoch 9)
# MRR after 24 epochs: 0.4691339 (best: 0.4754350; epoch 9)
# _synset_domain_usage_of
# MRR after 3 epochs: 0.7862342 (best: 0.8913067; epoch 0)
# MRR after 6 epochs: 0.9130459 (best: 0.9130459; epoch 6)
# MRR after 9 epochs: 0.9130459 (best: 0.9130459; epoch 9)
# MRR after 12 epochs: 0.9130459 (best: 0.9130459; epoch 12)
# MRR after 15 epochs: 0.8913068 (best: 0.9130459; epoch 12)
# MRR after 18 epochs: 0.8913068 (best: 0.9130459; epoch 12)
# MRR after 21 epochs: 0.8913068 (best: 0.9130459; epoch 12)
# MRR after 24 epochs: 0.8913068 (best: 0.9130459; epoch 12)
# _synset_domain_usage_of_reverse
# MRR after 3 epochs: 0.7463915 (best: 0.7695799; epoch 0)
# MRR after 6 epochs: 0.7862465 (best: 0.7862465; epoch 6)
# MRR after 9 epochs: 0.8369714 (best: 0.8369714; epoch 9)
# MRR after 12 epochs: 0.7391453 (best: 0.8369714; epoch 9)
# MRR after 15 epochs: 0.3012743 (best: 0.8369714; epoch 9)
# MRR after 18 epochs: 0.2065157 (best: 0.8369714; epoch 9)
# MRR after 21 epochs: 0.1837941 (best: 0.8369714; epoch 9)
# MRR after 24 epochs: 0.1707022 (best: 0.8369714; epoch 9)
# _verb_group
# MRR after 3 epochs: 0.6152432 (best: 0.6152432; epoch 3)
# MRR after 6 epochs: 0.6350617 (best: 0.6350617; epoch 6)
# MRR after 9 epochs: 0.6374202 (best: 0.6374202; epoch 9)
# MRR after 12 epochs: 0.6454462 (best: 0.6454462; epoch 12)
# MRR after 15 epochs: 0.6454492 (best: 0.6454492; epoch 15)
# MRR after 18 epochs: 0.6451278 (best: 0.6454492; epoch 15)
# MRR after 21 epochs: 0.6412586 (best: 0.6454492; epoch 15)
# MRR after 24 epochs: 0.6412658 (best: 0.6454492; epoch 15)
# MRR after 27 epochs: 0.6528937 (best: 0.6528937; epoch 27)
# MRR after 30 epochs: 0.6528975 (best: 0.6528975; epoch 30)
# MRR after 33 epochs: 0.6528994 (best: 0.6528994; epoch 33)
# MRR after 36 epochs: 0.6529014 (best: 0.6529014; epoch 36)
# MRR after 39 epochs: 0.6529077 (best: 0.6529077; epoch 39)
# MRR after 42 epochs: 0.6529120 (best: 0.6529120; epoch 42)
# MRR after 45 epochs: 0.6529142 (best: 0.6529142; epoch 45)
# MRR after 48 epochs: 0.6529213 (best: 0.6529213; epoch 48)
# _verb_group_reverse
# MRR after 3 epochs: 0.5408534 (best: 0.5408534; epoch 3)
# MRR after 6 epochs: 0.5656194 (best: 0.5656194; epoch 6)
# MRR after 9 epochs: 0.5662941 (best: 0.5662941; epoch 9)
# MRR after 12 epochs: 0.5666885 (best: 0.5666885; epoch 12)
# MRR after 15 epochs: 0.5781487 (best: 0.5781487; epoch 15)
# MRR after 18 epochs: 0.5782786 (best: 0.5782786; epoch 18)
# MRR after 21 epochs: 0.5782844 (best: 0.5782844; epoch 21)
# MRR after 24 epochs: 0.5785040 (best: 0.5785040; epoch 24)

# %%
print("#####################")
print("averaged results after fine tuning")
print("#####################")
print("on training data")
print('Hits @10: {0}'.format(np.mean(hits_train[9])))
print('Hits @3: {0}'.format(np.mean(hits_train[2])))
print('Hits @1: {0}'.format(np.mean(hits_train[0])))
print('Median rank: {0}'.format(np.median(ranks_train)))
print('Mean rank: {0}'.format(np.mean(ranks_train)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_train))))
print("on validation data")
print('Hits @10: {0}'.format(np.mean(hits_val[9])))
print('Hits @3: {0}'.format(np.mean(hits_val[2])))
print('Hits @1: {0}'.format(np.mean(hits_val[0])))
print('Median rank: {0}'.format(np.median(ranks_val)))
print('Mean rank: {0}'.format(np.mean(ranks_val)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_val))))
print("on testing data")
print('Hits @10: {0}'.format(np.mean(hits_test[9])))
print('Hits @3: {0}'.format(np.mean(hits_test[2])))
print('Hits @1: {0}'.format(np.mean(hits_test[0])))
print('Median rank: {0}'.format(np.median(ranks_test)))
print('Mean rank: {0}'.format(np.mean(ranks_test)))
print('Mean reciprocal rank: {0}'.format(np.mean(1./np.array(ranks_test))))
# Out:
# #####################
# averaged results after fine tuning
# #####################
# on training data
# Hits @10: 0.9983137964678102
# Hits @3: 0.9964967972737943
# Hits @1: 0.9611254082945659
# Median rank: 1.0
# Mean rank: 48.71440590489388
# Mean reciprocal rank: 0.9786217884774827
# on validation data
# Hits @10: 0.9273
# Hits @3: 0.8273
# Hits @1: 0.5734
# Median rank: 1.0
# Mean rank: 578.9741
# Mean reciprocal rank: 0.7087551350375052
# on testing data
# Hits @10: 0.9297
# Hits @3: 0.8297
# Hits @1: 0.576
# Median rank: 1.0
# Mean rank: 537.2202
# Mean reciprocal rank: 0.7116001909214152
